# %% [markdown]
# # Using several classifiers and tuning parameters - Parameters grid
# [From official `scikit-learn` documentation](http://scikit-learn.org/stable/auto_examples/model_selection/plot_grid_search_digits.html)
#
# Adapted by Claudio Sartori
#
# Example of usage of the ***model selection*** features of `scikit-learn` and comparison of several classification methods.
# 1. import a sample dataset
# 1. do the usual preliminary data explorations and separate the predicting attributes from the *target* `'Exited'`
# 1. define the _models_ that will be tested and prepare the _hyperparameter ranges_ for the modules
# 1. set the list of *score functions* to choose from
# 1. split the dataset into two parts: train and test
# 1. Loop on score functions and, for each score, loop on the model labels (see details below)
#     - optimize with GridSearchCV
#     - test
#     - store the results of best model
# 1. for each scoring show the best models for each classifier, sorted by decreasing performance
# 1. for each scoring show the confusion matrix of the prediction given by the best model

# %%
"""
@author: scikit-learn.org and Claudio Sartori
"""
import warnings
warnings.filterwarnings('ignore') # uncomment this line to suppress warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from sklearn.svm import SVC
from sklearn.linear_model import Perceptron
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier

print(__doc__) # print information included in the triple quotes at the beginning
# Out:
# @author: scikit-learn.org and Claudio Sartori

# %% [markdown]
# # 0. Initial settings
# Set the random state and set the seed with `np.random.seed()`
#
# Set the test set size and the number of cross valitadion splits

# %%
ts = 0.3 # test size
random_state = 42
np.random.seed(random_state) # this sets the random sequence. Setting only this the repeatability is guaranteed
                             # only if we re-execute the entire notebook
cv = 3   # number of cross-validation splits

target = 'Exited'

# %% [markdown]
# # 1. Import the dataset

# %%
df = pd.read_csv('churn-analysis.csv')
df.head(5)
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619       0   42       2       0.00              1          1
# 1          502       0   42       8  159660.80              3          1
# 2          699       0   39       1       0.00              2          0
# 3          822       1   50       7       0.00              2          1
# 4          501       1   44       4  142051.07              2          0
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88    True
# 1               0        113931.57    True
# 2               0         93826.63   False
# 3               1         10062.80   False
# 4               1         74940.50   False

# %% [markdown]
# # 2. Explore the data
#
# The output of exploration is not shown here

# %%
df[target].value_counts()
# Out:
# Exited
# False    4204
# True      810
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.pairplot(df, hue=target, height=2);

# %% [markdown]
# # 3. Define the _models_
# Prepare the _hyperparameter ranges_ for the modules
#
# Put everything in a dictionary, for ease of use
#
# Please read carefully these data structures and understand them
#
# It is also useful to read the API documentation of each classifier, in order to understand the hyperparameters

# %%
model_lbls = ['dt' # decision tree
             ,'nb' # gaussian naive bayes
             ,'lp'   # linear perceptron
      #        ,'svc'  # support vector # deactivate if running time becomes too long
             ,'knn'  # k nearest neighbours
             ,'adb'  # adaboost
             ,'rf'   # random forest
            ]

models = {
    'dt': {'name': 'Decision Tree       ',
           'estimator': DecisionTreeClassifier(random_state=random_state), 
           'param': [{'max_depth': [*range(1,20)],'class_weight':[None,'balanced']}],
          },
    'nb': {'name': 'Gaussian Naive Bayes',
           'estimator': GaussianNB(),
           'param': [{'var_smoothing': [10**exp for exp in range(-3,-13,-1)]}]
          },
    'lp': {'name': 'Linear Perceptron   ',
           'estimator': Perceptron(random_state=random_state),
           'param': [{'early_stopping': [True,False],'class_weight':[None,'balanced']}],
          },
    'svc':{'name': 'Support Vector      ',
           'estimator': SVC(random_state=random_state), 
           'param': [{'kernel': ['rbf'], 
                    'gamma': [1e-3, 1e-4],
                    'C': [1, 10, 100],
                    },
                    {'kernel': ['linear'],
                     'C': [1, 10, 100],                     
             },
                   ]
          },
    'knn':{'name': 'K Nearest Neighbor ',
           'estimator': KNeighborsClassifier(),
           'param': [{'n_neighbors': list(range(1,7))}]
       },
    'adb':{'name': 'AdaBoost           ',
           'estimator': AdaBoostClassifier(random_state=random_state),
           'param': [{'n_estimators':[10,20,30,40,50]
                     ,'learning_rate':[0.2,0.5,0.75,1,1.25,1.5]}]
          },
    'rf': {'name': 'Random forest       ',
           'estimator': RandomForestClassifier(random_state=random_state),
           'param': [{'max_depth': [*range(4,10)]
                     ,'n_estimators':[*range(10,60,10)]}]
          }

}

# %% [markdown]
# # 4. Set the list of *score functions* to choose from

# %%
scores = ['accuracy','precision_macro','recall_macro','f1_macro']

# %% [markdown]
# # 5. Split the dataset into the train and test parts
#     - the *train* part will be used for training and cross-validation (i.e. for *development*)
#     - the *test* part will be used for test (i.e. for *evaluation*)
#     - the fraction of test data will be _ts_ (a value of your choice between 0.2 and 0.5)

# %%
X = df.drop([target], axis = 1)
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y
                                                    , train_size = 1 - ts
                                                    , random_state = random_state)

print("There are {} samples in the training dataset".format(X_train.shape[0]))
print("There are {} samples in the testing dataset".format(X_test.shape[0]))
print("Each sample has {} features".format(X_train.shape[1]))
# Out:
# There are 3509 samples in the training dataset
# There are 1505 samples in the testing dataset
# Each sample has 9 features

# %% [markdown]
# # 6. Loop on scores and, for each score, loop on the model labels
#
# The function `GridSearchCV` iterates a cross validation experiment to train and test a model with different combinations of paramater values
# - for each parameter we have set before a list of values to test, `ParametersGrid` will be implicitly called to generate all the combinations
# - we choose a *score function* which will be used for the optimization
#     - e.g. `accuracy_score`, `precision_score`, `recall_score`, `f1_score`, see this [page](https://scikit-learn.org/stable/modules/model_evaluation.html) for reference
# - the output is a dataframe containing
#     - the set of parameters maximising the score
#     - the score used for optimisation and all the test scores
#
# ### Steps
#
# - prepare an empty list `clfs` to store all the fitte models
# - prepare an empty DataFrame which will collect the results of the fittings with each combination of parameters
#     - dataframe columns are `'scoring','model','best_params','accuracy','precision_macro','recall_macro','f1_macro'`
# - loop

# %%
clfs = []
results = pd.DataFrame(columns=['scoring','model','best_params'#,'fit+score_time'
                                ,'accuracy','precision_macro','recall_macro','f1_macro'])

skf = StratifiedKFold(n_splits=cv, random_state=random_state, shuffle=True)

for name in model_lbls:

    print('#'*40)
    print("# Tuning hyper-parameters for %s" % name)

    for score in scores:
        
        model = models[name]

        print('='*40)
        print("# Tuning hyper-parameters for %s" % score)
        clf = GridSearchCV(estimator = model['estimator'], param_grid = model['param']
                        , scoring = score
                        , return_train_score = False
                        #, refit = True #Refit the estimator using the best found parameters on the whole dataset
                        , cv = skf # use the splitter defined above
                        )
        
        clf.fit(X_train, y_train)
        best_params = clf.best_params_
        
        print(best_params)
        print("Best score {:6.3f}%".format(clf.best_score_*100))
        
        y_p = clf.best_estimator_.predict(X_test)
        cr = classification_report(y_test,y_p, zero_division=0, output_dict=True)
        
        macro = cr['macro avg']
        
        results.loc[len(results)] = [score, name, best_params, cr['accuracy'], macro['precision'], macro['recall'], macro['f1-score']]
        clfs.append(clf)

results.head(12)
# Out:
# ########################################
# # Tuning hyper-parameters for dt
# ========================================
# # Tuning hyper-parameters for accuracy
# {'class_weight': None, 'max_depth': 5}
# Best score 87.661%
# ========================================
# # Tuning hyper-parameters for precision_macro
# {'class_weight': None, 'max_depth': 3}
# Best score 87.799%
# ========================================
# # Tuning hyper-parameters for recall_macro
# {'class_weight': 'balanced', 'max_depth': 5}
# Best score 75.477%
# ========================================
# # Tuning hyper-parameters for f1_macro
# {'class_weight': None, 'max_depth': 6}
# Best score 70.726%
# ########################################
# # Tuning hyper-parameters for nb
# ========================================
# # Tuning hyper-parameters for accuracy
# {'var_smoothing': 1e-12}
# Best score 85.836%
# ========================================
# # Tuning hyper-parameters for precision_macro
# {'var_smoothing': 1e-12}
# Best score 81.144%
# ========================================
# # Tuning hyper-parameters for recall_macro
# {'var_smoothing': 1e-12}
# Best score 57.406%
# ========================================
# # Tuning hyper-parameters for f1_macro
# {'var_smoothing': 1e-12}
# Best score 59.090%
# ########################################
# # Tuning hyper-parameters for lp
# ========================================
# # Tuning hyper-parameters for accuracy
# {'class_weight': None, 'early_stopping': True}
# Best score 72.845%
# ========================================
# # Tuning hyper-parameters for precision_macro
# {'class_weight': 'balanced', 'early_stopping': True}
# Best score 52.630%
# ========================================
# # Tuning hyper-parameters for recall_macro
# {'class_weight': 'balanced', 'early_stopping': True}
# Best score 50.051%
# ========================================
# # Tuning hyper-parameters for f1_macro
# {'class_weight': None, 'early_stopping': False}
# Best score 44.487%
# ########################################
# # Tuning hyper-parameters for knn
# ========================================
# # Tuning hyper-parameters for accuracy
# {'n_neighbors': 4}
# Best score 84.013%
# ========================================
# # Tuning hyper-parameters for precision_macro
# {'n_neighbors': 4}
# Best score 60.883%
# ========================================
# # Tuning hyper-parameters for recall_macro
# {'n_neighbors': 1}
# Best score 51.802%
# ========================================
# # Tuning hyper-parameters for f1_macro
# {'n_neighbors': 1}
# Best score 51.802%
# ########################################
# # Tuning hyper-parameters for adb
# ========================================
# # Tuning hyper-parameters for accuracy
# {'learning_rate': 0.5, 'n_estimators': 30}
# Best score 87.803%
# ========================================
# # Tuning hyper-parameters for precision_macro
# {'learning_rate': 0.5, 'n_estimators': 10}
# Best score 88.629%
# ========================================
# # Tuning hyper-parameters for recall_macro
# {'learning_rate': 1.25, 'n_estimators': 10}
# Best score 69.034%
# ========================================
# # Tuning hyper-parameters for f1_macro
# {'learning_rate': 1.25, 'n_estimators': 10}
# Best score 71.735%
# ########################################
# # Tuning hyper-parameters for rf
# ========================================
# # Tuning hyper-parameters for accuracy
# {'max_depth': 9, 'n_estimators': 50}
# Best score 88.829%
# ========================================
# # Tuning hyper-parameters for precision_macro
# {'max_depth': 4, 'n_estimators': 30}
# Best score 87.922%
# ========================================
# # Tuning hyper-parameters for recall_macro
# {'max_depth': 9, 'n_estimators': 20}
# Best score 68.099%
# ========================================
# # Tuning hyper-parameters for f1_macro
# {'max_depth': 9, 'n_estimators': 30}
# Best score 72.498%
#             scoring model                                        best_params  \
# 0          accuracy    dt             {'class_weight': None, 'max_depth': 5}
# 1   precision_macro    dt             {'class_weight': None, 'max_depth': 3}
# 2      recall_macro    dt       {'class_weight': 'balanced', 'max_depth': 5}
# 3          f1_macro    dt             {'class_weight': None, 'max_depth': 6}
# 4          accuracy    nb                           {'var_smoothing': 1e-12}
# 5   precision_macro    nb                           {'var_smoothing': 1e-12}
# 6      recall_macro    nb                           {'var_smoothing': 1e-12}
# 7          f1_macro    nb                           {'var_smoothing': 1e-12}
# 8          accuracy    lp     {'class_weight': None, 'early_stopping': True}
# 9   precision_macro    lp  {'class_weight': 'balanced', 'early_stopping':...
# 10     recall_macro    lp  {'class_weight': 'balanced', 'early_stopping':...
# 11         f1_macro    lp    {'class_weight': None, 'early_stopping': False}
#
#     accuracy  precision_macro  recall_macro  f1_macro
# 0   0.872425         0.883192      0.644462  0.686507
# 1   0.844518         0.903267      0.551521  0.550767
# 2   0.793355         0.687829      0.768597  0.707909
# 3   0.878405         0.829549      0.698285  0.737855
# 4   0.849169         0.815833      0.583241  0.602023
# 5   0.849169         0.815833      0.583241  0.602023
# 6   0.849169         0.815833      0.583241  0.602023
# 7   0.849169         0.815833      0.583241  0.602023
# 8   0.827243         0.413621      0.500000  0.452727
# 9   0.174751         0.586551      0.501205  0.149963
# 10  0.174751         0.586551      0.501205  0.149963
# 11  0.179402         0.545071      0.502495  0.156498

# %% [markdown]
# ### Parameters to collect
#
# `classification_report` produces a dictionary containing some classification performance measures, given the *ground truth* and the *predictions* (use the parameter `output_dict=True`)
#
# The measures are (among others):
# - `accuracy`
# - `macro avg` a dictionary containing:
#     - `precision`
#     - `recall`
#     - `f1-score`
# - ...

# %% [markdown]
# ### Loop
#
# - repeat for all the chosen scorings
#     - repeat for all the chosen classification models
#         - store in `clf` the initialisation of `GridSearchCV` with the appropriate
#             - classification model
#             - parameters ranges
#             - scoring
#             - cross validation method `cv` (the same for all)
#         - fit `clf` with the *train* part of `X` and `y`
#         - store in `y_pred` the prediction for the *test* part of `X`
#         - append `clf` to clfs`
#         - append `y_pred` to `y_preds`
#         - store in variable `cr` the `classification_report` produced with the test part of `y` and `y_pred`
#         - store in the last row of `results` a list containing:
#             - the name of the model
#             - the `.best_params_` of `clf`
#             - a selection of the contents of cr
#                 - 'accuracy',
#                 - 'macro avg''precision'
#                 - 'macro avg''recall'
#                 - 'macro avg''f1-score'
#
# Hints:
# - cr is a multi-level dictionary, second level can be reached
# with <br> `cr['first level label']['second level label']`
# - to append a list as the last row of a dataframe you can use <br>
# `df.loc[len(df)]=[]`

# %% [markdown]
# # 7. Display
#
# For each scoring show the ranking of the models, and the confusion matrix given by the best model
#
# For each scoring:
# - set a `scoring_filter`
# - filter the results of that scoring
# - display the filtered dataframe with the `display()` function (it allows several displays of dataframes )

# %%
df2 = results.query("scoring == 'accuracy'")
display(df2)
# Out:
#      scoring model                                     best_params  accuracy  \
# 0   accuracy    dt          {'class_weight': None, 'max_depth': 5}  0.872425
# 4   accuracy    nb                        {'var_smoothing': 1e-12}  0.849169
# 8   accuracy    lp  {'class_weight': None, 'early_stopping': True}  0.827243
# 12  accuracy   knn                              {'n_neighbors': 4}  0.823920
# 16  accuracy   adb      {'learning_rate': 0.5, 'n_estimators': 30}  0.879734
# 20  accuracy    rf            {'max_depth': 9, 'n_estimators': 50}  0.879734
#
#     precision_macro  recall_macro  f1_macro
# 0          0.883192      0.644462  0.686507
# 4          0.815833      0.583241  0.602023
# 8          0.413621      0.500000  0.452727
# 12         0.615541      0.513207  0.486464
# 16         0.853044      0.685395  0.729258
# 20         0.857886      0.682352  0.726816

# %% [markdown]
# # 8. Confusion matrices
#
# Use the `ConfusionMatrixDisplay` with the best model of each scoring to compare the predictions
#
# Repeat for every scoring:
# - filter the results for the current scoring
# - find the row with the best value of the scoring
# - display the confusion matrix with an appropriate title

# %%
from sklearn.metrics import confusion_matrix

for score in scores:
    df2 = results.query("scoring == '" + score + "'")
    print(score)
    df2 = df2.sort_values(by=score, ascending=False)

    print(df2)
    df2 = df2.head(1)
    display(df2)
    
    for index, row in df2.iterrows():
        clf = clfs[index]

        y_p = clf.best_estimator_.predict(X_test)
        cm = confusion_matrix(y_test, y_p, labels=clf.best_estimator_.classes_, normalize='true')
        disp = ConfusionMatrixDisplay(confusion_matrix=cm
                                    , display_labels=clf.classes_)
        
        disp.plot()
        disp.ax_.set_title("Best Model for '{}': '{}".format(score,row['model']))
# Out:
# accuracy
#      scoring model                                     best_params  accuracy  \
# 16  accuracy   adb      {'learning_rate': 0.5, 'n_estimators': 30}  0.879734
# 20  accuracy    rf            {'max_depth': 9, 'n_estimators': 50}  0.879734
# 0   accuracy    dt          {'class_weight': None, 'max_depth': 5}  0.872425
# 4   accuracy    nb                        {'var_smoothing': 1e-12}  0.849169
# 8   accuracy    lp  {'class_weight': None, 'early_stopping': True}  0.827243
# 12  accuracy   knn                              {'n_neighbors': 4}  0.823920
#
#     precision_macro  recall_macro  f1_macro
# 16         0.853044      0.685395  0.729258
# 20         0.857886      0.682352  0.726816
# 0          0.883192      0.644462  0.686507
# 4          0.815833      0.583241  0.602023
# 8          0.413621      0.500000  0.452727
# 12         0.615541      0.513207  0.486464
#      scoring model                                 best_params  accuracy  \
# 16  accuracy   adb  {'learning_rate': 0.5, 'n_estimators': 30}  0.879734
#
#     precision_macro  recall_macro  f1_macro
# 16         0.853044      0.685395  0.729258
# precision_macro
#             scoring model                                        best_params  \
# 1   precision_macro    dt             {'class_weight': None, 'max_depth': 3}
# 21  precision_macro    rf               {'max_depth': 4, 'n_estimators': 30}
# 17  precision_macro   adb         {'learning_rate': 0.5, 'n_estimators': 10}
# 5   precision_macro    nb                           {'var_smoothing': 1e-12}
# 13  precision_macro   knn                                 {'n_neighbors': 4}
# 9   precision_macro    lp  {'class_weight': 'balanced', 'early_stopping':...
#
#     accuracy  precision_macro  recall_macro  f1_macro
# 1   0.844518         0.903267      0.551521  0.550767
# 21  0.867110         0.902391      0.621470  0.657836
# 17  0.841196         0.864607      0.544949  0.539738
# 5   0.849169         0.815833      0.583241  0.602023
# 13  0.823920         0.615541      0.513207  0.486464
# 9   0.174751         0.586551      0.501205  0.149963
#            scoring model                             best_params  accuracy  \
# 1  precision_macro    dt  {'class_weight': None, 'max_depth': 3}  0.844518
#
#    precision_macro  recall_macro  f1_macro
# 1         0.903267      0.551521  0.550767
# recall_macro
#          scoring model                                        best_params  \
# 2   recall_macro    dt       {'class_weight': 'balanced', 'max_depth': 5}
# 18  recall_macro   adb        {'learning_rate': 1.25, 'n_estimators': 10}
# 22  recall_macro    rf               {'max_depth': 9, 'n_estimators': 20}
# 6   recall_macro    nb                           {'var_smoothing': 1e-12}
# 14  recall_macro   knn                                 {'n_neighbors': 1}
# 10  recall_macro    lp  {'class_weight': 'balanced', 'early_stopping':...
#
#     accuracy  precision_macro  recall_macro  f1_macro
# 2   0.793355         0.687829      0.768597  0.707909
# 18  0.874419         0.811279      0.698919  0.734798
# 22  0.880399         0.854085      0.687319  0.731352
# 6   0.849169         0.815833      0.583241  0.602023
# 14  0.728239         0.523914      0.523842  0.523877
# 10  0.174751         0.586551      0.501205  0.149963
#         scoring model                                   best_params  accuracy  \
# 2  recall_macro    dt  {'class_weight': 'balanced', 'max_depth': 5}  0.793355
#
#    precision_macro  recall_macro  f1_macro
# 2         0.687829      0.768597  0.707909
# f1_macro
#      scoring model                                      best_params  accuracy  \
# 3   f1_macro    dt           {'class_weight': None, 'max_depth': 6}  0.878405
# 19  f1_macro   adb      {'learning_rate': 1.25, 'n_estimators': 10}  0.874419
# 23  f1_macro    rf             {'max_depth': 9, 'n_estimators': 30}  0.881728
# 7   f1_macro    nb                         {'var_smoothing': 1e-12}  0.849169
# 15  f1_macro   knn                               {'n_neighbors': 1}  0.728239
# 11  f1_macro    lp  {'class_weight': None, 'early_stopping': False}  0.179402
#
#     precision_macro  recall_macro  f1_macro
# 3          0.829549      0.698285  0.737855
# 19         0.811279      0.698919  0.734798
# 23         0.858480      0.689643  0.734337
# 7          0.815833      0.583241  0.602023
# 15         0.523914      0.523842  0.523877
# 11         0.545071      0.502495  0.156498
#     scoring model                             best_params  accuracy  \
# 3  f1_macro    dt  {'class_weight': None, 'max_depth': 6}  0.878405
#
#    precision_macro  recall_macro  f1_macro
# 3         0.829549      0.698285  0.737855
